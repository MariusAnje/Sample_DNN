# %%
import torch
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
# %matplotlib inline
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import torchvision

# %%
model = torchvision.models.vgg16(pretrained=True).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /home/yanzy/.torch/models/vgg16-397923af.pth
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-70-0ecd33c78021> in <module>()
# ----> 1 model = torchvision.models.vgg16(pretrained=True).to(device)
#
# /home/yanzy/Envs/fp/local/lib/python2.7/site-packages/torchvision/models/vgg.pyc in vgg16(pretrained, **kwargs)
#     150     model = VGG(make_layers(cfg['D']), **kwargs)
#     151     if pretrained:
# --> 152         model.load_state_dict(model_zoo.load_url(model_urls['vgg16']))
#     153     return model
#     154
#
# /home/yanzy/Envs/fp/local/lib/python2.7/site-packages/torch/utils/model_zoo.pyc in load_url(url, model_dir, map_location, progress)
#      63         sys.stderr.write('Downloading: "{}" to {}\n'.format(url, cached_file))
# ...

# %%
import PIL

# %%
img = PIL.Image.open('timg.jpg')
img = torch.Tensor(np.array(img)).to(device)
img = img.transpose(0,2).transpose(1,2)
print img.size()
it = torch.nn.functional.interpolate(img.view(1,3,650,1200), size=224, scale_factor=None, mode='nearest', align_corners=None)
print it.size()
Show = it.view(3,224,224).transpose(0,2)
plt.imshow(np.uint8(Show.data.cpu().numpy()))
print img.size()
# Out:
# torch.Size([3, 650, 1200])
# torch.Size([1, 3, 224, 224])
# torch.Size([3, 650, 1200])

# %%
print model(it.view(1,3,224,224)).argmax()
# Out:
# tensor(105, device='cuda:0')
